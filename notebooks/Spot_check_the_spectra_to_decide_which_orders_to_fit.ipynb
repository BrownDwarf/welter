# %%
import os
import json
import numpy as np
import h5py

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
# %config InlineBackend.figure_format = 'retina'
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %% [markdown]
# Read in the data.

# %%
f2 = h5py.File("../data/reduced/LkCa4_IGRINS_H_clean.hdf5", 'r')

# %% [markdown]
# Which orders to use for full spectrum fitting?

# %%
for key in f2.keys():
    print(key)
# Out:
# fls
# masks
# sigmas
# wls

# %%
i=0

# %%
# %matplotlib inline

# %%
i=22

# %%
print(i)
plt.plot(f2['wls'][i,:], f2['fls'][i,:])
plt.ylim(0, 1)
i += 1
# Out:
# 22

# %% [markdown]
# # The end.

# %%
f2.close()
